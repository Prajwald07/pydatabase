# %%
import pandas as pd
df=pd.read_excel("Dataset/SaleData.xlsx")
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %% [markdown]
# 1. Write a Pandas program to create a Pivot table with multiple indexes from a given excel sheet (Salesdata.xlsx).

# %%
table1=pd.pivot_table(df,index=['Region','Manager','SalesMan','Item'])
table1
# Out:
#                                              Sale_amt  Unit_price      Units
# Region  Manager SalesMan  Item
# Central Douglas John      Desk             250.000000       125.0   2.000000
#                           Home Theater   43500.000000       500.0  87.000000
#                           Television     80266.000000      1198.0  67.000000
#         Hermann Luis      Home Theater   26250.000000       500.0  52.500000
#                           Television     75474.000000      1198.0  63.000000
#                           Video Games     2925.000000        58.5  50.000000
#                 Shelli    Desk             625.000000       125.0   5.000000
#                           Home Theater   25000.000000       500.0  50.000000
#                           Video Games     4036.500000        58.5  69.000000
#                 Sigal     Home Theater   14000.000000       500.0  28.000000
#                           Television    107820.000000      1198.0  90.000000
# ...

# %% [markdown]
# 2. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise.

# %%
table2=pd.pivot_table(df,index=['Region','Manager'],values='Sale_amt',aggfunc='sum')
table2
# Out:
#                  Sale_amt
# Region  Manager
# Central Douglas  124016.0
#         Hermann  365108.5
#         Martha   199690.0
#         Timothy  140955.0
# East    Douglas   48204.0
#         Martha   272803.0
# West    Douglas   66836.0
#         Timothy   88063.0

# %% [markdown]
# 3. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise.

# %%
table2=pd.pivot_table(df,index=['Region','Manager','SalesMan'],values='Sale_amt',aggfunc='sum')
table2
# Out:
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John       124016.0
#         Hermann Luis       206373.0
#                 Shelli      33698.0
#                 Sigal      125037.5
#         Martha  Steven     199690.0
#         Timothy David      140955.0
# East    Douglas Karen       48204.0
#         Martha  Alexander  236703.0
#                 Diana       36100.0
# West    Douglas Michael     66836.0
#         Timothy Stephen     88063.0

# %% [markdown]
# 4. Write a Pandas program to create a Pivot table and find the item wise unit sold.

# %%
table4=pd.pivot_table(df,index=['Item'],values='Units',aggfunc='count')
table4
# Out:
#               Units
# Item
# Cell Phone        5
# Desk              3
# Home Theater     15
# Television       13
# Video Games       7

# %% [markdown]
# 5. Write a Pandas program to create a Pivot table and find the region wise total sale.

# %%
table5=pd.pivot_table(df,index=['Region'],values='Sale_amt',aggfunc='sum')
table5
# Out:
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %% [markdown]
# 6. Write a Pandas program to create a Pivot table and find the region wise, item wise unit sold .

# %%
table6=pd.pivot_table(df,index=['Region','Item'],values='Units',aggfunc='sum')
table6
# Out:
#                       Units
# Region  Item
# Central Cell Phone     27.0
#         Desk            7.0
#         Home Theater  424.0
#         Television    498.0
#         Video Games   243.0
# East    Cell Phone    175.0
#         Home Theater  234.0
#         Television    130.0
#         Video Games   152.0
# West    Cell Phone     76.0
#         Desk            3.0
#         Home Theater   64.0
#         Television     88.0

# %% [markdown]
# 7. Write a Pandas program to create a Pivot table and count the manager wise sale and mean value of sale amount.

# %%
table7=pd.pivot_table(df,index=['Manager'],values='Sale_amt',aggfunc=['count','mean'])
table7
# Out:
#            count          mean
#         Sale_amt      Sale_amt
# Manager
# Douglas        8  29882.000000
# Hermann       12  30425.708333
# Martha        14  33749.500000
# Timothy        9  25446.444444

# %% [markdown]
# 8. Write a Pandas program to create a Pivot table and find manager wise, salesman wise total sale and also display the sum of all sale amount at the bottom.

# %%
table8=pd.pivot_table(df,index=['Manager','SalesMan'],values=['Units','Sale_amt'],aggfunc='sum',fill_value=0,margins=True)
table8
# Out:
#                     Sale_amt  Units
# Manager SalesMan
# Douglas John        124016.0    156
#         Karen        48204.0    170
#         Michael      66836.0     89
# Hermann Luis        206373.0    281
#         Shelli       33698.0    193
#         Sigal       125037.5    173
# Martha  Alexander   236703.0    396
#         Diana        36100.0    125
#         Steven      199690.0    183
# Timothy David       140955.0    213
#         Stephen      88063.0    142
# All                1305675.5   2121

# %% [markdown]
# 9. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise where Manager = "Douglas".

# %%
table9=pd.pivot_table(df,index=['Region','Manager','SalesMan'],values='Sale_amt')
print(table9.query('Manager==["Douglas"]'))
# Out:
#                               Sale_amt
# Region  Manager SalesMan
# Central Douglas John      41338.666667
# East    Douglas Karen     16068.000000
# West    Douglas Michael   33418.000000

# %% [markdown]
# 10. Write a Pandas program to create a Pivot table and find the region wise Television and Home Theater sold.

# %%
table10=pd.pivot_table(df,index=['Region','Item'],values='Units')
print(table10.query('Item==["Television","Home Theater"]'))
# Out:
#                           Units
# Region  Item
# Central Home Theater  53.000000
#         Television    55.333333
# East    Home Theater  46.800000
#         Television    65.000000
# West    Home Theater  32.000000
#         Television    44.000000

# %% [markdown]
# 11. Write a Pandas program to create a Pivot table and find the maximum sale value of the items.

# %%
table11=pd.pivot_table(df,index=['Item'],values='Sale_amt',aggfunc='max')
table11
# Out:
#               Sale_amt
# Item
# Cell Phone     21600.0
# Desk             625.0
# Home Theater   47000.0
# Television    113810.0
# Video Games     5616.0

# %% [markdown]
# 12. Write a Pandas program to create a Pivot table and find the minimum sale value of the items.

# %%
table12=pd.pivot_table(df,index=['Item'],values='Sale_amt',aggfunc='min')
table12
# Out:
#               Sale_amt
# Item
# Cell Phone      3375.0
# Desk             250.0
# Home Theater    2000.0
# Television      8386.0
# Video Games      936.0

# %% [markdown]
# 13.Write a Pandas program to create a Pivot table and find the maximum and minimum sale value of the items.

# %%
table13=pd.pivot_table(df,index=['Item'],values='Sale_amt',aggfunc=['min','max'])
table13
# Out:
#                   min       max
#              Sale_amt  Sale_amt
# Item
# Cell Phone     3375.0   21600.0
# Desk            250.0     625.0
# Home Theater   2000.0   47000.0
# Television     8386.0  113810.0
# Video Games     936.0    5616.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Dataset/mtcars.csv')
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# 1. histogram to check the frequency distribution of the variable ‘mpg’ (Miles per gallon) and note down the interval having the highest frequency.

# %%
sns.histplot(x="mpg", data=df)
plt.show()

# %% [markdown]
# 2. scatter plot to determine the relation between weight of the car and mpg

# %%
sns.scatterplot(x="wt", y="mpg", data=df)
plt.show()

# %% [markdown]
# 3. bar plot to check the frequency distribution of transmission type of cars.

# %%
sns.countplot(data=df,x='am')
plt.show()

# %% [markdown]
# 4. Box and Whisker plot of mpg and interpret the five number summary.

# %%
sns.boxplot(data=df,x='mpg')
plt.show()

# %%
df['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %% [markdown]
# 5. Create a git repository and push source code to repo.
